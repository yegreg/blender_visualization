# %%
import numpy as np
from numpy.lib import stride_tricks
import scipy.io.wavfile as wav
from matplotlib import pyplot as plt

# %%
AUDIO_PATH = "C:/Users/Yegreg/Music/Koalas are never sad/Soundscapes of Koalia/10 - Party nextdoors.wav"

# %%
rate, audio = wav.read(AUDIO_PATH)
# Out:
# C:\Users\Yegreg\Anaconda3\envs\py35\lib\site-packages\scipy\io\wavfile.py:267: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)

# %%
rate
# Out:
# 44100

# %%
audio.size / rate
# Out:
# 68.0

# %%
frame_audio = list()
sample_per_frame = rate // 24
for i in range(34 * 24):
    frame_audio.append(np.sum(np.exp(audio[i * sample_per_frame: (i + 1) * sample_per_frame, 0])))

# %%
plt.plot(frame_audio[30:40])
plt.show()

# %%
fft_window_size = 2 ** 13
fps = 24
# size of window to have fps number of frames per second
window_size = fft_window_size

# smooth window for sliding convolution
smooth_window = np.hanning(window_size)

# size we step in the signal between windows
hop_size = rate // fps

# zeros at beginning (thus center of 1st window should be for sample nr. 0)
samples = np.append(np.zeros(np.int(window_size / 2.0)), audio)

# number of windows
number_of_columns = np.int((len(samples) - window_size) / float(hop_size)) + 1

# zeros at end (thus samples can be fully covered by frames)
samples = np.append(samples, np.zeros(window_size))

# chop up sample into windows for Fourier transform
frames = stride_tricks.as_strided(samples[48:], shape=(number_of_columns, window_size),
                                  strides=(samples.strides[0] * hop_size, samples.strides[0])).copy()

# %%
plt.plot(audio[rate * 4 - window_size // 2: rate * 4 - window_size // 2 + 16])
plt.plot(frames[fps * 4, :16])
plt.show()

# %%
# smooth out the windows
frames *= smooth_window

# %%
plt.plot(frames[fps * 4,])
plt.show()

# %%
# do the Fourier transform
fourier = np.fft.rfft(frames)

# %%
fourier.shape
# Out:
# (6357, 4097)

# %%
6723 / 24
# Out:
# 280.125

# %%
fourier = np.abs(fourier)

# %%
renorm = fourier / np.max(fourier, axis=0)

# %%
decibels = np.log(renorm)

# %%
plt.plot(renorm[3 * fps, :])
plt.show()
plt.plot(renorm[10 * fps, :])
plt.show()
plt.plot(decibels[20 * fps, :1000])
plt.show()
plt.plot(decibels[30 * fps, :1000])
plt.show()

# %% [markdown]
# # Frequencies

# %%
frequency = 440
sine = np.sin(np.arange(rate) * 2 * np.pi * frequency / rate)
plt.plot(sine[:500])
plt.show()

# %%
windowed_sine = sine[:2 ** 13] * smooth_window

# %%
plt.plot(windowed_sine)
plt.show()

# %%
fft_sine = np.fft.rfft(windowed_sine)

# %%
fft_sine.shape
# Out:
# (4097,)

# %%
plt.plot(np.abs(fft_sine[:100]))
plt.show()

# %%
print(np.argmax(fft_sine))
# Out:
# 81

# %%
rate / 2 ** 13 * 81
# Out:
# 436.04736328125

# %%
rate / 2 ** 13
# Out:
# 5.38330078125

# %%
n_buckets = 40

# %%
alpha = np.power(2, - 1 / 4)

# %%
alpha
# Out:
# 0.8408964152537145

# %%
seq = np.arange(n_buckets)
segments = np.power(alpha, seq)
buckets = 2 ** 12 * segments
print(buckets)
frequencies = buckets * rate / 2 ** 13
print(frequencies)
# Out:
# [ 4096.          3444.31171688  2896.30937574  2435.49617153  2048.
#   1722.15585844  1448.15468787  1217.74808576  1024.           861.07792922
#    724.07734394   608.87404288   512.           430.53896461   362.03867197
#    304.43702144   256.           215.2694823    181.01933598   152.21851072
#    128.           107.63474115    90.50966799    76.10925536    64.
#     53.81737058    45.254834      38.05462768    32.            26.90868529
#     22.627417      19.02731384    16.            13.45434264    11.3137085
#      9.51365692     8.             6.72717132     5.65685425     4.75682846]
# [ 22050.          18541.76595634  15591.70452516  13111.0084429   11025.
#    9270.88297817   7795.85226258   6555.50422145   5512.5          4635.44148909
#    3897.92613129   3277.75211073   2756.25         2317.72074454
#    1948.96306565   1638.87605536   1378.125        1158.86037227
#     974.48153282    819.43802768    689.0625        579.43018614
# ...

# %%
buckets = buckets.astype(np.int32)

# %%
buckets = np.append(buckets, 0)[::-1]
buckets
# Out:
# array([   0,    4,    5,    6,    7,    9,   11,   13,   15,   19,   22,
#          26,   31,   38,   45,   53,   63,   76,   90,  107,  127,  152,
#         181,  215,  255,  304,  362,  430,  511,  608,  724,  861, 1023,
#        1217, 1448, 1722, 2047, 2435, 2896, 3444, 4096])

# %%
renorm.shape
# Out:
# (6357, 4097)

# %%
log_spectrum = np.zeros([renorm.shape[0], n_buckets])
for i in range(n_buckets):
    log_spectrum[:, i] = np.mean(renorm[:, buckets[i]: buckets[i + 1]], axis=1)

# %%
log_spectrum.shape
# Out:
# (6357, 40)

# %%
spec = log_spectrum

# %%
max_spec = spec.copy()
for i in range(8, spec.shape[0] - 1):
    max_spec[i, :] = np.max(spec[i - 8: i + 1, :], axis=0)

# %%
np.savez("eyes_closed.npz", spec=spec, max_spec=max_spec)

# %%
plt.plot(spec[10 * fps, :])
plt.show()

# %% [markdown]
# # Animation

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
           frames=200, interval=20, blit=True)

plt.show()

# %% [markdown]
# # Smoothing

# %%
x = np.linspace(0, 5, 1000)

# %%
y = np.zeros(x.shape)

# %%
y[200:300] = 1
y[500:550] = 1
y[600:800] = 1

# %%
plt.plot(x, y)
plt.show()

# %%
def get_half_window(size):
    half_window = np.hanning(WINDOW_SIZE)
    half_window[WINDOW_SIZE // 2:] = 0
    return half_window

# %%
smoothing = np.convolve(y, half_window)
smoothing /= np.max(smoothing)
plt.plot(smoothing)
plt.show()

# %%
max_spec.shape
# Out:
# (5646, 40)

# %%
smooth_max = []
for i in range(max_spec.shape[1]):
    smoothing = np.convolve(max_spec[:, i], get_half_window(5))
    smoothing /= np.max(smoothing)
    smooth_max.append(smoothing)
plt.plot(max_spec[3000:3500, 20])
plt.plot(smooth_max[20][3000:3500])
plt.show()

# %%
max_spec.shape
# Out:
# (5646, 40)

# %%
spec /= np.max(spec)
plt.plot(spec[:, 20])
plt.show()
